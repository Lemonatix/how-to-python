# %%
from PIL import Image
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
import colorsys
from tqdm import tqdm

p = "/home/mmr/how-to-python/chem_python/IMG_1849.png"
image = Image.open(p)
image_array = np.array(image)

# %%
img = np.array(deepcopy(image_array[1500:3500,800:3200,:])/256)

# %%
plt.imshow(img, origin='upper')

# %%
hsv = np.zeros_like(img)
for i in tqdm(range(img.shape[0])):
    for j in range(img.shape[1]):
        hsv[i,j,:] = deepcopy(colorsys.rgb_to_hsv(deepcopy(img[i,j,0]),deepcopy(img[i,j,1]),deepcopy(img[i,j,2])))
# Out:
# 100%|██████████| 2000/2000 [01:53<00:00, 17.68it/s]

# %%
deepcopy(colorsys.rgb_to_hsv(deepcopy(img[i,j,0]/256),deepcopy(img[i,j,1]/256),deepcopy(img[i,j,2]/256)))
# Out:
# (np.float64(0.4166666666666667),
#  np.float64(0.009615384615384616),
#  np.float64(0.003173828125))

# %%
i,j = 1234,562
colorsys.rgb_to_hsv(img[i,j,0]/256,img[i,j,1]/256,img[i,j,2]/256)
# Out:
# (np.float64(0.19540229885057472),
#  np.float64(0.14356435643564355),
#  np.float64(0.003082275390625))

# %%
plt.imshow(hsv[:,:,0])

# %%
plt.imshow(hsv[:,:,1])

# %%
plt.imshow(hsv[:,:,2])
