# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(3)
y = np.random.normal(3, 5, 9) # mean, standard deviation, number of samples
plt.hist(y, 10000)
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 0., 0., 1.]),
#  array([0.23717224, 0.30435152, 0.3715308 , 0.43871008, 0.50588936,
#         0.57306864, 0.64024792, 0.7074272 , 0.77460648, 0.84178576,
#         0.90896504]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Pixelformate:
# - .bmp
# - .png
# - .jpeg
# - .tift
# - .gif
#
# Vektorgrafiken:
# - .svg

# %%
mat = np.zeros([100,100,3]) # [n,m,k]
for n in range(100):
    for m in range(100): 
        mat[n,m,:] = np.random.rand()

plt.imshow(mat, cmap = "gray", label = "test")
plt.colorbar()
plt.show()

# %%
n, m, k = 100,100,3
mat = np.zeros([n,m,k]) # [n,m,k]
for n_ in range(n):
    for m_ in range(m): 
        mat[n_,m_,:] = np.random.rand(k)*0.9

plt.imshow(mat)
plt.colorbar()
plt.show()
